# %% [markdown]
# ### Critical proportion
# Key policy lever to pull is the proportion of immune individuals:
#
# $$
# 1-s > 1-\frac{1}{R0}
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

xs = np.arange(0, 5, .01)

def sq(x):
    y = .2*x**2 + 2
    return y

ax.plot(xs, sq(xs))

ax.set(xlim = [0, 5], ylim = [0, sq(5)], xticks = [1.5, 2.5], yticks = )

a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 11
#       7 ax.plot(xs, ys)
#       9 ax.set(xlim = [0, 5], ylim = [0, .2*5**2+2], xticks = [1.5, 2.5])
# ---> 11 a
#
# NameError: name 'a' is not defined
